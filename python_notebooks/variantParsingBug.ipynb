# %%
import pysam

# %%
f = pysam.VariantFile('http://s3.amazonaws.com/1000genomes/release/20130502/ALL.chr5.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz')

# %%
f.fetch("5",0,1000000).next().alleles
# Out:
# ('T', 'A')

# %%
name = f.fetch("5",22112,50855)

# %%
for i in name:
    if i.start == 22112:
        myVar = i
        break

# %%
print (myVar.alleles)
# Out:
# ('G', '<CN0>', '<CN2>')

# %%
print (list(myVar.alts))
print([x for x in myVar.info.iteritems()])
print(myVar.__str__())
# Out:
# ['<CN0>', '<CN2>']
# [('AC', (9, 1)), ('AF', (0.001797119970433414, 0.000199681002413854)), ('AN', 5008), ('CS', 'DUP_gs'), ('END', 50855), ('NS', 2504), ('SVTYPE', 'CNV'), ('DP', 19385), ('EAS_AF', (0.0, 0.0)), ('AMR_AF', (0.0, 0.0)), ('AFR_AF', (0.0, 0.0)), ('EUR_AF', (0.0010000000474974513, 0.0010000000474974513)), ('SAS_AF', (0.008200000040233135, 0.0)), ('VT', ('SV',))]
# ...

# %%
v2 = f.fetch("5", 47247, 47248)

# %%
for v in v2:
    if v.start == 47247:
        myVar2 = v
        break
print([x for x in myVar2.info.iteritems()])
print(myVar2.__str__())
# INFO.AA	Ancestral Allele. Format: AA|REF|ALT|IndelType. AA: Ancestral allele, REF:Reference Allele, ALT:Alternate Allele, IndelType:Type of Indel (REF, ALT and IndelType are only defined for indels)
# Out:
# [('AC', (1,)), ('AF', (0.000199681002413854,)), ('AN', 5008), ('NS', 2504), ('DP', 14055), ('EAS_AF', (0.0,)), ('AMR_AF', (0.0,)), ('AFR_AF', (0.0007999999797903001,)), ('EUR_AF', (0.0,)), ('SAS_AF', (0.0,)), ('AA', 'N|||'), ('VT', ('SNP',))]
# ...
